# %% [markdown]
# # By liulu

# %% [markdown]
# # --------------------------------第十三章 Matplotlib库-------------------------------------------

# %% [markdown]
# ## 1.环境配置

# %% [markdown]
# （1）要不要plt.show()?
#
# ipython 中可用魔术方法%matplotlib inline
#
# pycharm中必须使用 plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.ylabel("squares")
#plt.style.use("seaborn-whitegrid")
# Out:
# Text(0, 0.5, 'squares')

# %% [markdown]
# （2）设置样式

# %%
plt.style.available[:]
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
with plt.style.context("seaborn-darkgrid"):  #临时设置风格
    plt.plot(x,y)

# %% [markdown]
# （3）将图像保存为文件

# %%
import numpy as np
x = np.linspace(0,10,100)
plt.plot(x,np.exp(x))
plt.savefig("my_figure1.png")

# %% [markdown]
# ## 2.Matplotlib库

# %% [markdown]
# ### 2.1 折线图

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid") 
import numpy as np

# %%
x = np.linspace(0, 2*np.pi, 100)
plt.plot(x,np.sin(x))

# %% [markdown]
# #### 绘制多条曲线

# %%
x = np.linspace(0, 2*np.pi, 100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %% [markdown]
# （1）调整线条颜色和风格

# %%
x = np.linspace(0, 2*np.pi, 100)
offsets = np.linspace(0, np.pi, 5)
colors = ["blue","g","r","yellow","pink"]
for offset,color in zip(offsets,colors):
    plt.plot(x,np.sin(x-offset),c=color)

# %%
x = np.linspace(0,10,11)
offsets = list(range(8))
linestyles = ["solid","dashed","dashdot","dotted","-","--","-.",":"]
for offset,linestyle in zip(offsets,linestyles):
    plt.plot(x,x+offset,linestyle=linestyle)

# %% [markdown]
# （2）调整线宽

# %%
x = np.linspace(0,10,11)
offsets = list(range(5))
linewidths = [i*2 for i in range(1,5)]
for offset,linewidth in zip(offsets,linewidths):
    plt.plot(x,x+offset,linewidth=linewidth)

# %% [markdown]
# （3）调整数据点标记

# %%
x = np.linspace(0,10,11)
offsets = list(range(5))
markers = ["*","+","o","s"]
for offset,marker in zip(offsets,markers):
    plt.plot(x,x+offset,marker=marker,markersize=10)

# %% [markdown]
# #### 颜色和风格设置的简写

# %%
x = np.linspace(0,10,11)
offsets = list(range(0,8,2))
color_marker_linestyles = ["g*-","b+--","ko-.","rs:"]
for offset,color_marker_linestyle in zip(offsets,color_marker_linestyles):
    plt.plot(x,x+offset,color_marker_linestyle)

# %% [markdown]
# #### 调整坐标轴

# %% [markdown]
# xlim,ylim

# %%
x = np.linspace(0, 2*np.pi, 100)
plt.plot(x,np.sin(x))
plt.xlim(-1,7)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# axis

# %%
x = np.linspace(0, 2*np.pi, 100)
plt.plot(x,np.sin(x))
plt.axis([-2,8,-2,2])
# Out:
# [-2, 8, -2, 2]

# %%
# ?plt.axis #获取axis还有哪些用法

# %% [markdown]
# 对数坐标

# %%
x = np.logspace(0,5,100)
plt.plot(x,np.log(x))
plt.xscale("log")

# %% [markdown]
# 调整坐标轴刻度

# %%
x = np.linspace(0,10,100)
plt.plot(x,x**2)
plt.xticks(np.arange(0,12,step=1))
plt.yticks(np.arange(0,110,step=10))
# Out:
# ([<matplotlib.axis.YTick at 0x1144271abe0>,
#   <matplotlib.axis.YTick at 0x114427ce630>,
#   <matplotlib.axis.YTick at 0x1144270b7b8>,
#   <matplotlib.axis.YTick at 0x1144227e390>,
#   <matplotlib.axis.YTick at 0x114422b10b8>,
#   <matplotlib.axis.YTick at 0x11442227978>,
#   <matplotlib.axis.YTick at 0x114428edac8>,
#   <matplotlib.axis.YTick at 0x114422f3908>,
#   <matplotlib.axis.YTick at 0x11442721828>,
#   <matplotlib.axis.YTick at 0x11442721400>,
#   <matplotlib.axis.YTick at 0x114427217f0>],
#  <a list of 11 Text yticklabel objects>)

# %%
x = np.linspace(0,10,100)
plt.plot(x,x**2)

# %% [markdown]
# 调整刻度样式

# %%
x = np.linspace(0,10,100)
plt.plot(x,x**2)
plt.tick_params(axis="both",labelsize=15)

# %% [markdown]
# #### 设置图形标签

# %%
x = np.linspace(0, 2*np.pi, 100)
plt.plot(x,np.sin(x))
plt.title("A Sine Curve",fontsize=20)
plt.xlabel("x",fontsize=15)
plt.ylabel("sin(x)",fontsize=15)
# Out:
# Text(0,0.5,'sin(x)')

# %% [markdown]
# #### 设置图例

# %%
x = np.linspace(0, 2*np.pi, 100)
plt.plot(x,np.sin(x),"b-",label="Sin")
plt.plot(x,np.cos(x),"r--",label="Cos")
plt.axis([-2,8,-1.5,1.5])
plt.title("A Sine Curve",fontsize=20)
plt.xlabel("x",fontsize=15)
plt.ylabel("sin(x)",fontsize=15)
plt.legend(loc="best",frameon=True,fontsize=10)

# %% [markdown]
# #### 添加文字和箭头

# %%
x = np.linspace(0, 2*np.pi, 100)
plt.plot(x,np.sin(x),"b-")
plt.text(3.5,0.5, "y=sin(x)",fontsize=15)
# Out:
# Text(3.5,0.5,'y=sin(x)')

# %% [markdown]
# ### 2.2 散点图

# %% [markdown]
# #### （1）简单散点图

# %%
x = np.linspace(0, 2*np.pi, 100)
plt.scatter(x,np.sin(x),marker=".",s=30,c="r")  #s大小，c颜色

# %% [markdown]
# #### （2）颜色配置

# %%
x = np.linspace(0,10,10)
y = x**2
#plt.scatter(x,y,c=y,cmap="Blues")
plt.scatter(x,y,c=y,cmap="inferno")
plt.colorbar()

# %% [markdown]
# #### （3）根据数据控制点的大小

# %%
x, y, colors, size = (np.random.rand(100) for i in range(4))
plt.scatter(x,y,c=colors,s=100*size,cmap="viridis")     #映射的思想

# %% [markdown]
# #### （4）透明度

# %%
x, y, colors, size = (np.random.rand(100) for i in range(4))
plt.scatter(x,y,c=colors,s=100*size,cmap="viridis",alpha=0.3)
plt.colorbar()

# %% [markdown]
# ### 2.3 柱形图

# %% [markdown]
# #### （1）简单柱形图

# %%
x = np.arange(1,6)
plt.bar(x, 2*x, align="center", width=0.5, alpha=0.5, color="blue")
plt.xticks(x,('G1','G2','G3','G4','G5'))
plt.tick_params(axis="both",labelsize=10)

# %%
x = np.arange(1,6)
colors = ['red','blue','yellow','green','gray']
plt.bar(x, 2*x, align="center", width=0.5, alpha=0.5, color=colors)
plt.xticks(x,('G1','G2','G3','G4','G5'))
plt.tick_params(axis="both",labelsize=10)

# %% [markdown]
# #### （2）累加柱形图

# %%
x = np.arange(1,6)
y1 = np.random.randint(20,30,size=5)
y2 = np.random.randint(20,30,size=5)
plt.bar(x,y1,width=0.5,label="man")
plt.bar(x,y2,width=0.5,bottom=y1,label="woman")
plt.legend()

# %% [markdown]
# #### （3）并列柱形图

# %%
x = np.arange(15)
y1 = x+1
y2 = y1+np.random.randint(10,size=15)
plt.bar(x,y1,width=0.5,label="man")
plt.bar(x+0.3,y2,width=0.5,label="woman")
plt.legend()

# %% [markdown]
# #### （4）横向柱形图

# %%
x = np.arange(5)
y = 2*x
plt.barh(x,y,align="center",height=0.5,alpha=0.8,color="b")
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ### 2.4 多子图

# %% [markdown]
# #### （1）简单多子图

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)

t1 = np.arange(0.0,5.0,0.1)
t2 = np.arange(0.0,5.0,0.02)

plt.subplot(211)   #两行一列的第一个
plt.plot(t1,f(t1),"bo-",markerfacecolor='r',markersize=5)
plt.title("A tale of 2 subplots")
plt.ylabel("Damped oscillation")

plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2),"r--")
plt.xlabel("time(s)")
plt.ylabel("Undamped")
# Out:
# Text(0,0.5,'Undamped')

# %% [markdown]
# #### （2）多行多列子图

# %%
x = np.random.random(10)
y = np.random.random(10)

plt.subplots_adjust(hspace=0.5,wspace=0.3)
plt.style.use("seaborn-whitegrid") 

plt.subplot(321)
plt.scatter(x,y,s=80,c='b',marker=">")

plt.subplot(322)
plt.scatter(x,y,s=80,c='g',marker="*")

plt.subplot(323)
plt.scatter(x,y,s=80,c='r',marker="s")

plt.subplot(324)
plt.scatter(x,y,s=80,c='c',marker="p")

plt.subplot(325)
plt.scatter(x,y,s=80,c='m',marker="+")

plt.subplot(326)
plt.scatter(x,y,s=80,c='y',marker="H")

# %% [markdown]
# #### （3）不规则多子图

# %%
def f(x):
    return np.exp(-x)*np.cos(2*np.pi*x)

x = np.arange(0.0, 3.0, 0.01)
grid = plt.GridSpec(2,3,wspace=0.4,hspace=0.3)

plt.subplot(grid[0,0])
plt.plot(x,f(x))

plt.subplot(grid[0,1:])
plt.plot(x,f(x),'r--',lw=2)

plt.subplot(grid[1,:])
plt.plot(x,f(x),'g-',lw=3)

# %% [markdown]
# ### 2.5 直方图

# %% [markdown]
# #### （1）普通频次直方图

# %%
mu, sigma = 100,15
x = mu + sigma*np.random.randn(10000)   #正态分布

plt.hist(x, bins=50, facecolor='g', alpha=0.75)  #bins 有效的坐标轴分为50个区间
# Out:
# (array([  3.,   7.,   2.,   2.,  10.,  11.,  17.,  27.,  35.,  44.,  70.,
#         109., 149., 147., 210., 240., 284., 326., 398., 444., 538., 537.,
#         505., 567., 630., 578., 556., 527., 499., 444., 370., 333., 294.,
#         243., 208., 153., 124., 113.,  75.,  49.,  44.,  25.,  16.,   9.,
#          10.,   7.,   5.,   4.,   0.,   2.]),
#  array([ 46.18525377,  48.37315284,  50.56105191,  52.74895099,
#          54.93685006,  57.12474913,  59.31264821,  61.50054728,
#          63.68844635,  65.87634543,  68.0642445 ,  70.25214357,
#          72.44004265,  74.62794172,  76.81584079,  79.00373987,
#          81.19163894,  83.37953801,  85.56743708,  87.75533616,
#          89.94323523,  92.1311343 ,  94.31903338,  96.50693245,
#          98.69483152, 100.8827306 , 103.07062967, 105.25852874,
#         107.44642782, 109.63432689, 111.82222596, 114.01012504,
#         116.19802411, 118.38592318, 120.57382226, 122.76172133,
#         124.9496204 , 127.13751948, 129.32541855, 131.51331762,
#         133.7012167 , 135.88911577, 138.07701484, 140.26491392,
#         142.45281299, 144.64071206, 146.82861114, 149.01651021,
#         151.20440928, 153.39230836, 155.58020743]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### （2）概率密度

# %%
mu, sigma = 100,15    #均值，标准差
x = mu + sigma*np.random.randn(10000)

plt.hist(x, 50, density=True, color='r',histtype='step')
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, 0.025, r'$\mu=100,\ \sigma=15$')
plt.xlim(40,160)
plt.ylim(0,0.03)
# Out:
# (0, 0.03)

# %%
from scipy.stats import norm
mu, sigma = 100,15
x = mu + sigma*np.random.randn(10000)
_,bins,_=plt.hist(x, 50, density=True)
y = norm.pdf(bins, mu, sigma)
plt.plot(bins, y, 'r--', lw=3)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, 0.025, r'$\mu=100,\ \sigma=15$')
plt.xlim(40,160)
plt.ylim(0,0.03)
# Out:
# (0, 0.03)

# %% [markdown]
# #### （3）累计概率分布

# %%
mu, sigma = 100,15    #均值，标准差
x = mu + sigma*np.random.randn(10000)

plt.hist(x, 50, density=True, color='r',cumulative=True)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, 0.025, r'$\mu=100,\ \sigma=15$')
plt.xlim(40,160)
plt.ylim(0,0.03)
# Out:
# (0, 0.03)

# %% [markdown]
# ### 2.6 误差图

# %% [markdown]
# #### （1）基本误差图

# %%
x = np.linspace(0, 10, 50)
dy = 0.5
y = np.sin(x) + dy*np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt='+b')
# Out:
# <Container object of 3 artists>

# %% [markdown]
# #### （2）柱形图误差图

# %%
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menstd = (2, 3, 4, 1, 2)
womenstd = (3, 5, 2, 3, 3)
ind = ['G1','G2','G3','G4','G5']
width=0.35

p1 = plt.bar(ind,menMeans,width=width, label='Men',yerr=menstd)
p1 = plt.bar(ind,womenMeans,width=width, bottom=menMeans, label='Women',yerr=womenstd)

plt.ylabel('Scores')
plt.title("Scores by group and gender")
plt.yticks(np.arange(0,81,10))
plt.legend()

# %% [markdown]
# ### 2.7 面向对象的风格简介

# %% [markdown]
# ### 2.8 三维图形简介

# %% [markdown]
# #### （1）三维数据点与线

# %%
from mpl_toolkits import mplot3d

ax = plt.axes(projection="3d")
zline = np.linspace(0,15,100)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline,yline,zline)

zdata = 15*np.random.random(100)
xdata = np.sin(zdata)
ydata = np.cos(zdata)
ax.scatter3D(xdata,ydata,zdata,c=zdata,cmap='spring')

# %% [markdown]
# #### （2）三维数据曲面图

# %%
def f(x,y):
    return np.sin(np.sqrt(x**2+y**2))

x = np.linspace(-6,6,30)
y = np.linspace(-6,6,30)
X,Y = np.meshgrid(x,y)
Z = f(X,Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X,Y,Z,cmap='viridis')

# %% [markdown]
# ## 3.Seaborn库

# %% [markdown]
# 是一个基于matplotlib且数据结构与pandas统一的统计图制作库

# %% [markdown]
# #### （1）折线图的对比

# %%
x = np.linspace(0,10,500)
y = np.cumsum(np.random.randn(500,6),axis=0)

with plt.style.context("classic"):
    plt.plot(x,y)
    plt.legend("ABCDEF",ncol=2,loc='upper left')

# %%
import seaborn as sns
x = np.linspace(0,10,500)
y = np.cumsum(np.random.randn(500,6),axis=0)
sns.set()
plt.plot(x,y)
plt.legend("ABCDEF",ncol=2,loc='upper left')

# %% [markdown]
# #### （2）柱状图的对比

# %%
x = ['G1','G2','G3','G4','G5']
y = 2*np.arange(1,6)

plt.figure(figsize=(8,4))
plt.barh(x,y,align="center",height=0.5,alpha=0.8,color="blue")
plt.tick_params(axis="both",labelsize=13)

# %%
import seaborn as sns
x = ['G1','G2','G3','G4','G5']
y = 2*np.arange(5,0,-1)
sns.barplot(y,x,linewidth=5)

# %%
sns.barplot?

# %%
iris = sns.load_dataset("iris",engine='python')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data=iris,hue="species")

# %% [markdown]
# ## 4.Pandas中的绘图函数概览

# %%
import pandas as pd

# %% [markdown]
# #### （1）线形图

# %%
df = pd.DataFrame(np.random.randn(1000,4).cumsum(axis=0),
                 columns=list("ABCD"),
                 index=np.arange(1000))
df.head()
# Out:
#           A         B         C         D
# 0 -0.503141  0.309966 -0.998584 -0.273602
# 1 -0.739960 -0.743927 -0.130230  2.034723
# 2 -0.172091 -1.491546 -0.227680  1.526860
# 3 -1.018558 -2.664322 -0.020190  1.150210
# 4 -0.844039 -2.011912 -0.634840 -0.100815

# %%
df.plot()

# %%
df = pd.DataFrame()
df.plot?

# %% [markdown]
# #### （2）柱形图

# %%
df2 = pd.DataFrame(np.random.rand(10,4),columns=list("abcd"))
df2
# Out:
#           a         b         c         d
# 0  0.187936  0.731297  0.628270  0.063401
# 1  0.752888  0.677502  0.703783  0.242503
# 2  0.690172  0.983151  0.175339  0.477546
# 3  0.217891  0.495699  0.803224  0.563516
# 4  0.013783  0.929467  0.002242  0.317013
# 5  0.243941  0.823066  0.378880  0.435371
# 6  0.652559  0.504086  0.883681  0.208141
# 7  0.097728  0.512020  0.288851  0.501202
# 8  0.904726  0.799229  0.377795  0.082362
# 9  0.683738  0.011702  0.547885  0.187202

# %%
df2.plot.bar()

# %%
df2.plot.barh()

# %% [markdown]
# #### （3）直方图

# %%
df3 = pd.DataFrame({"A":np.random.randn(1000)+3,
                    "B":np.random.randn(1000),
                   "C":np.random.randn(1000)-3})
df3
# Out:
#             A         B         C
# 0    3.497364 -0.382311 -2.838195
# 1    2.426721  0.085583 -5.144156
# 2    4.337538  0.615478 -4.417756
# 3    3.828092 -0.881546 -3.779802
# 4    1.772640 -0.883080 -3.741525
# 5    3.310174  1.431804 -3.359743
# 6    1.945842  0.730333 -3.137791
# 7    3.580281 -0.508303 -1.914819
# 8    1.533657  0.642950 -2.296104
# 9    2.712026  0.636086 -1.992785
# 10   4.515511  0.061273 -2.730062
# 11   3.621368 -0.655269 -3.220181
# 12   0.474570  0.179003 -3.741130
# 13   3.321029  0.093503 -4.345800
# 14   4.057066 -0.049757 -3.200905
# 15   2.092723 -0.065062 -2.634516
# 16   3.128614 -0.973044 -2.489525
# 17   4.728049  1.507445 -2.957147
# 18   3.520002 -0.320435 -2.653132
# 19   3.913080 -1.079927 -1.665418
# 20   1.520648  1.161309 -2.949873
# 21   3.492239  0.332596 -3.329122
# 22   3.614099 -0.593371 -7.046397
# 23   2.053864 -0.435971 -1.711335
# 24   4.501917  0.985812 -1.894437
# 25   5.591650  0.240335 -2.403484
# 26   4.618797 -0.045165 -4.322510
# 27   1.999425  0.138910 -3.023755
# 28   1.269579  0.112468 -1.796142
# 29   1.523450 -0.235041 -3.036388
# ..        ...       ...       ...
# 970  5.612732  1.240922 -3.639922
# 971  3.166158  0.533358 -4.418111
# 972  2.787394  0.026376 -2.913707
# 973  3.678441  1.218482 -2.003172
# 974  1.863266 -0.568637 -3.943866
# 975  1.875650 -1.679878 -2.368525
# 976  1.996858 -0.370895 -3.500237
# 977  2.620441 -0.149330 -4.034267
# 978  3.607900 -0.597627 -2.756597
# 979  3.719129 -0.300951 -4.200832
# 980  2.951579 -0.986746 -3.106199
# 981  3.082826 -0.678064 -3.162193
# 982  3.484164 -0.023305 -2.102671
# 983  2.841937  0.057559 -1.245661
# 984  1.483104  2.236390 -4.591360
# 985  3.377088  1.343231 -0.861541
# 986  1.970243 -1.693031 -2.084953
# 987  2.666459  1.102836 -4.507601
# 988  3.156858 -0.652466 -1.911359
# 989  4.301659  0.757172 -3.824819
# 990  3.923977 -0.204070 -4.366571
# 991  1.994875 -0.211106 -2.153295
# 992  3.682373  2.389788 -3.039178
# 993  2.655302  1.382889 -4.103931
# 994  1.916096 -0.739987 -3.200683
# 995  1.934938  0.081622 -2.625063
# 996  1.775425  0.696470 -3.390356
# 997  4.334592 -1.114956 -4.541454
# 998  2.641534 -1.629604 -1.811232
# 999  6.098763  1.345792 -4.231413
#
# [1000 rows x 3 columns]

# %%
df3.plot.hist(bins=20)
